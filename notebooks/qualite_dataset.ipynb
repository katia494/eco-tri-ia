# %% [markdown]
# # C3 — Audit reproductible du dataset ECO-TRI
#
# Ce notebook affiche le rapport produit par `scripts/audit_dataset.py`. Les valeurs ne sont pas simulées.

# %%
from pathlib import Path
import json
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
from scripts.audit_dataset import audit_dataset

source = PROJECT_ROOT / 'data/raw/Garbage classification/Garbage classification'
report = audit_dataset(source)
report

# %%
output = PROJECT_ROOT / 'reports/data_quality.json'
output.parent.mkdir(parents=True, exist_ok=True)
output.write_text(json.dumps(report, indent=2, ensure_ascii=False), encoding='utf-8')
print(f'Rapport enregistré : {output}')
